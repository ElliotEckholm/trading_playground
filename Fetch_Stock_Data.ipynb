# %%
# import modules
from pandas_datareader import data as pdr
import matplotlib.pyplot as plt
  
# initializing Parameters
start = "2000-01-01"
end = "2021-10-24"
symbols = ["VOO"]
  
# Getting the data
data = pdr.get_data_yahoo(symbols, start, end)
  
# Display
plt.figure(figsize = (20,10))
plt.title('Opening Prices from {} to {}'.format(start, end))
plt.plot(data['Open'])
plt.show()

data.head(10)
# Out:
# Attributes  Adj Close       Close        High         Low        Open   Volume
# Symbols           VOO         VOO         VOO         VOO         VOO      VOO
# Date
# 2010-09-09  81.648964  101.320000  102.500000  101.139999  102.500000  26500.0
# 2010-09-10  82.019646  101.779999  101.860001  101.300003  101.680000   8600.0
# 2010-09-13  83.051132  103.059998  103.139999  102.500000  102.959999  33750.0
# 2010-09-14  83.035042  103.040001  103.480003  102.379997  102.839996  59400.0
# 2010-09-15  83.244560  103.300003  103.379997  102.400002  102.620003   9250.0
# 2010-09-16  83.212341  103.260002  103.320000  102.699997  103.019997  59550.0
# 2010-09-17  83.292915  103.360001  103.879997  103.019997  103.879997  49350.0
# 2010-09-20  84.646736  105.040001  105.040001  103.459999  103.739998  19000.0
# 2010-09-21  84.388870  104.720001  105.440002  104.279999  105.019997  19250.0
# 2010-09-22  83.937607  104.160004  105.040001  103.959999  104.559998  18100.0
